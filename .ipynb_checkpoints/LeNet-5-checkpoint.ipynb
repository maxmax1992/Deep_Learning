# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fd5552aec81d> in <module>()
#       1 from __future__ import print_function
# ----> 2 import keras
#       3 from keras.datasets import mnist
#       4 from keras.models import Sequential
#       5 from keras.layers import Dense, Dropout, Flatten
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/keras/__init__.py in <module>()
#       2
#       3 from . import utils
# ----> 4 from . import activations
#       5 from . import applications
#       6 from . import backend
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/keras/activations.py in <module>()
#       4 from . import backend as K
#       5 from .utils.generic_utils import deserialize_keras_object
# ----> 6 from .engine import Layer
#       7
#       8
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/keras/engine/__init__.py in <module>()
#       6 from .topology import Layer
#       7 from .topology import get_source_inputs
# ----> 8 from .training import Model
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/keras/engine/training.py in <module>()
#      23 from .. import metrics as metrics_module
#      24 from ..utils.generic_utils import Progbar
# ---> 25 from .. import callbacks as cbks
#      26 from ..legacy import interfaces
#      27
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/keras/callbacks.py in <module>()
#      24 if K.backend() == 'tensorflow':
#      25     import tensorflow as tf
# ---> 26     from tensorflow.contrib.tensorboard.plugins import projector
#      27
#      28
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/__init__.py in <module>()
#      25 from tensorflow.contrib import copy_graph
#      26 from tensorflow.contrib import crf
# ---> 27 from tensorflow.contrib import cudnn_rnn
#      28 from tensorflow.contrib import data
#      29 from tensorflow.contrib import deprecated
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/cudnn_rnn/__init__.py in <module>()
#      26 from __future__ import print_function
#      27
# ---> 28 from tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops import CudnnGRU
#      29 from tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops import CudnnLSTM
#      30 from tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops import CudnnRNNRelu
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/cudnn_rnn/python/ops/cudnn_rnn_ops.py in <module>()
#      19
#      20 from tensorflow.contrib.cudnn_rnn.ops import gen_cudnn_rnn_ops
# ---> 21 from tensorflow.contrib.rnn.python.ops import lstm_ops
#      22 from tensorflow.contrib.util import loader
#      23 from tensorflow.python.framework import common_shapes
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/rnn/__init__.py in <module>()
#      79 from tensorflow.contrib.rnn.python.ops.lstm_ops import *
#      80 from tensorflow.contrib.rnn.python.ops.rnn import *
# ---> 81 from tensorflow.contrib.rnn.python.ops.rnn_cell import *
#      82
#      83 from tensorflow.python.ops.rnn import static_bidirectional_rnn
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/rnn/python/ops/rnn_cell.py in <module>()
#      23
#      24 from tensorflow.contrib.compiler import jit
# ---> 25 from tensorflow.contrib.layers.python.layers import layers
#      26 from tensorflow.python.framework import dtypes
#      27 from tensorflow.python.framework import op_def_registry
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/layers/__init__.py in <module>()
#     100
#     101 # pylint: disable=unused-import,wildcard-import
# --> 102 from tensorflow.contrib.layers.python.layers import *
#     103 # pylint: enable=unused-import,wildcard-import
#     104
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/__init__.py in <module>()
#      29 from tensorflow.contrib.layers.python.layers.regularizers import *
#      30 from tensorflow.contrib.layers.python.layers.summaries import *
# ---> 31 from tensorflow.contrib.layers.python.layers.target_column import *
#      32 from tensorflow.contrib.layers.python.ops.bucketization_op import *
#      33 from tensorflow.contrib.layers.python.ops.sparse_feature_cross_op import *
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/target_column.py in <module>()
#      22
#      23 from tensorflow.contrib.framework import deprecated
# ---> 24 from tensorflow.contrib.losses.python.losses import loss_ops
#      25 from tensorflow.contrib.metrics.python.ops import metric_ops
#      26 from tensorflow.python.framework import ops
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/losses/__init__.py in <module>()
#      24
#      25 # pylint: disable=wildcard-import
# ---> 26 from tensorflow.contrib.losses.python.losses import *
#      27 # pylint: enable=wildcard-import
#      28
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/__init__.py in <module>()
#      23
#      24 # pylint: disable=wildcard-import
# ---> 25 from tensorflow.contrib.losses.python.losses.loss_ops import *
#      26 # pylint: enable=wildcard-import
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py in <module>()
#     204 @deprecated("2016-12-30", "Use tf.losses.add_loss instead.")
#     205 @add_arg_scope
# --> 206 def add_loss(loss, loss_collection=ops.GraphKeys.LOSSES):
#     207   """Adds a externally defined loss to the collection of losses.
#     208
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py in add_arg_scope(func)
#     182   _add_op(func)
#     183   setattr(func_with_args, '_key_op', _key_op(func))
# --> 184   return tf_decorator.make_decorator(func, func_with_args)
#     185
#     186
#
# ~/.conda/envs/capsenv/lib/python3.6/site-packages/tensorflow/python/util/tf_decorator.py in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#      84   """
#      85   if decorator_name is None:
# ---> 86     decorator_name = _inspect.stack()[1][3]  # Caller's name.
#      87   decorator = TFDecorator(decorator_name, target, decorator_doc,
#      88                           decorator_argspec)
#
# ~/.conda/envs/capsenv/lib/python3.6/inspect.py in stack(context)
#    1489 def stack(context=1):
#    1490     """Return a list of records for the stack above the caller's frame."""
# -> 1491     return getouterframes(sys._getframe(1), context)
#    1492
#    1493 def trace(context=1):
#
# ~/.conda/envs/capsenv/lib/python3.6/inspect.py in getouterframes(frame, context)
#    1466     framelist = []
#    1467     while frame:
# -> 1468         frameinfo = (frame,) + getframeinfo(frame, context)
#    1469         framelist.append(FrameInfo(*frameinfo))
#    1470         frame = frame.f_back
#
# ~/.conda/envs/capsenv/lib/python3.6/inspect.py in getframeinfo(frame, context)
#    1440         start = lineno - 1 - context//2
#    1441         try:
# -> 1442             lines, lnum = findsource(frame)
#    1443         except OSError:
#    1444             lines = index = None
#
# ~/.conda/envs/capsenv/lib/python3.6/inspect.py in findsource(object)
#     763     is raised if the source code cannot be retrieved."""
#     764
# --> 765     file = getsourcefile(object)
#     766     if file:
#     767         # Invalidate cache if needed.
#
# ~/.conda/envs/capsenv/lib/python3.6/inspect.py in getsourcefile(object)
#     691         return filename
#     692     # only return a non-existent filename if the module has a PEP 302 loader
# --> 693     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     694         return filename
#     695     # or it is in the linecache
#
# ~/.conda/envs/capsenv/lib/python3.6/inspect.py in getmodule(object, _filename)
#     728     # Copy sys.modules in order to cope with changes while iterating
#     729     for modname, module in list(sys.modules.items()):
# --> 730         if ismodule(module) and hasattr(module, '__file__'):
#     731             f = module.__file__
#     732             if f == _filesbymodname.get(modname, None):
#
# KeyboardInterrupt:

# %% [markdown]
# get the minst dataset

# %%
batch_size = 128
num_classes = 10
epochs = 100

# input image dimensions
img_rows, img_cols = 28, 28

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()

model.add(Conv2D(6, (5, 5), activation='relu', input_shape = input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
